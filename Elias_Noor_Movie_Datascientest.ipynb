# %%
# Streamlit installation for pretty UI
# !pip -q install streamlit 

# Localtunnel installation to test it locally
# !npm install -g localtunnel > /dev/null
# Out:
#      |████████████████████████████████| 9.7 MB 5.1 MB/s
#      |████████████████████████████████| 4.3 MB 59.0 MB/s
#      |████████████████████████████████| 111 kB 56.7 MB/s
#      |████████████████████████████████| 76 kB 4.3 MB/s
#      |████████████████████████████████| 164 kB 68.3 MB/s
#      |████████████████████████████████| 180 kB 69.8 MB/s
#      |████████████████████████████████| 63 kB 1.3 MB/s
#      |████████████████████████████████| 128 kB 70.7 MB/s
#      |████████████████████████████████| 792 kB 59.0 MB/s
#      |████████████████████████████████| 380 kB 73.3 MB/s
#   Building wheel for blinker (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.28 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.9.0 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.31.1 which is incompatible.

# %%
# !pip install fuzzywuzzy IMDbPy # Fuzzywuzzy to make our UI pretty
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting IMDbPy
#   Downloading IMDbPY-2021.4.18-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 5.4 MB/s
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.7/dist-packages (from IMDbPy) (1.4.31)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from IMDbPy) (4.2.6)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy->IMDbPy) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy->IMDbPy) (4.10.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy->IMDbPy) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy->IMDbPy) (3.7.0)
# Installing collected packages: IMDbPy, fuzzywuzzy
# Successfully installed IMDbPy-2021.4.18 fuzzywuzzy-0.18.0

# %%
# Our movies list :

import pandas as pd
movies = pd.read_csv('df_initial.csv')
movie_names = {movie.title: movie.imdbId for index, movie in movies[['imdbId', 'title']].drop_duplicates().iterrows()}
movie_names
# Out:
# {'Toy Story (1995)': 'tt0114709',
#  'Jumanji (1995)': 'tt0113497',
#  'Grumpier Old Men (1995)': 'tt0113228',
#  'Waiting to Exhale (1995)': 'tt0114885',
#  'Father of the Bride Part II (1995)': 'tt0113041',
#  'Heat (1995)': 'tt0113277',
#  'Sabrina (1995)': 'tt0114319',
#  'Tom and Huck (1995)': 'tt0112302',
#  'Sudden Death (1995)': 'tt0114576',
#  'GoldenEye (1995)': 'tt0113189',
#  'American President, The (1995)': 'tt0112346',
#  'Dracula: Dead and Loving It (1995)': 'tt0112896',
#  'Balto (1995)': 'tt0112453',
#  'Nixon (1995)': 'tt0113987',
#  'Cutthroat Island (1995)': 'tt0112760',
#  'Casino (1995)': 'tt0112641',
#  'Sense and Sensibility (1995)': 'tt0114388',
#  'Four Rooms (1995)': 'tt0113101',
#  'Ace Ventura: When Nature Calls (1995)': 'tt0112281',
#  'Money Train (1995)': 'tt0113845',
#  'Get Shorty (1995)': 'tt0113161',
#  'Copycat (1995)': 'tt0112722',
#  'Assassins (1995)': 'tt0112401',
#  'Powder (1995)': 'tt0114168',
#  'Leaving Las Vegas (1995)': 'tt0113627',
#  'Othello (1995)': 'tt0114057',
#  'Now and Then (1995)': 'tt0114011',
#  'Persuasion (1995)': 'tt0114117',
#  'City of Lost Children, The (Cité des enfants perdus, La) (1995)': 'tt0112682',
#  'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)': 'tt0115012',
#  'Dangerous Minds (1995)': 'tt0112792',
#  'Twelve Monkeys (a.k.a. 12 Monkeys) (1995)': 'tt0114746',
#  'Wings of Courage (1995)': 'tt0114952',
#  'Babe (1995)': 'tt0112431',
#  'Carrington (1995)': 'tt0112637',
#  'Dead Man Walking (1995)': 'tt0112818',
#  'Across the Sea of Time (1995)': 'tt0112286',
#  'It Takes Two (1995)': 'tt0113442',
#  'Clueless (1995)': 'tt0112697',
#  'Cry, the Beloved Country (1995)': 'tt0112749',
#  'Richard III (1995)': 'tt0114279',
#  'Dead Presidents (1995)': 'tt0112819',
#  'Restoration (1995)': 'tt0114272',
#  'Mortal Kombat (1995)': 'tt0113855',
#  'To Die For (1995)': 'tt0114681',
#  'How to Make an American Quilt (1995)': 'tt0113347',
#  'Seven (a.k.a. Se7en) (1995)': 'tt0114369',
#  'Pocahontas (1995)': 'tt0114148',
#  'When Night Is Falling (1995)': 'tt0114916',
#  'Usual Suspects, The (1995)': 'tt0114814',
#  'Guardian Angel (1994)': 'tt0109950',
#  'Mighty Aphrodite (1995)': 'tt0113819',
#  'Lamerica (1994)': 'tt0110299',
#  'Big Green, The (1995)': 'tt0112499',
#  'Georgia (1995)': 'tt0113158',
#  'Kids of the Round Table (1995)': 'tt0113541',
#  'Home for the Holidays (1995)': 'tt0113321',
#  'Postman, The (Postino, Il) (1994)': 'tt0110877',
#  'Confessional, The (Confessionnal, Le) (1995)': 'tt0112714',
#  'Indian in the Cupboard, The (1995)': 'tt0113419',
#  'Eye for an Eye (1996)': 'tt0116260',
#  "Mr. Holland's Opus (1995)": 'tt0113862',
#  "Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)": 'tt0116126',
#  'Two if by Sea (1996)': 'tt0118002',
#  'Bio-Dome (1996)': 'tt0115683',
#  'Lawnmower Man 2: Beyond Cyberspace (1996)': 'tt0116839',
#  'Two Bits (1995)': 'tt0114753',
#  'French Twist (Gazon maudit) (1995)': 'tt0113149',
#  'Friday (1995)': 'tt0113118',
#  'From Dusk Till Dawn (1996)': 'tt0116367',
#  'Fair Game (1995)': 'tt0113010',
#  'Kicking and Screaming (1995)': 'tt0113537',
#  'Misérables, Les (1995)': 'tt0113828',
#  'Bed of Roses (1996)': 'tt0115644',
#  'Big Bully (1996)': 'tt0115676',
#  'Screamers (1995)': 'tt0114367',
#  'Nico Icon (1995)': 'tt0113973',
#  'Crossing Guard, The (1995)': 'tt0112744',
#  'Juror, The (1996)': 'tt0116731',
#  'White Balloon, The (Badkonake sefid) (1995)': 'tt0112445',
#  "Things to Do in Denver When You're Dead (1995)": 'tt0114660',
#  "Antonia's Line (Antonia) (1995)": 'tt0112379',
#  'Once Upon a Time... When We Were Colored (1995)': 'tt0114039',
#  'Last Summer in the Hamptons (1995)': 'tt0113612',
#  'Angels and Insects (1995)': 'tt0112365',
#  'White Squall (1996)': 'tt0118158',
#  'Dunston Checks In (1996)': 'tt0116151',
#  'Black Sheep (1996)': 'tt0115697',
#  'Nick of Time (1995)': 'tt0113972',
#  'The Journey of August King (1995)': 'tt0113490',
#  'Mary Reilly (1996)': 'tt0117002',
#  'Vampire in Brooklyn (1995)': 'tt0114825',
#  'Beautiful Girls (1996)': 'tt0115639',
#  'Broken Arrow (1996)': 'tt0115759',
#  'In the Bleak Midwinter (1995)': 'tt0113403',
#  'Hate (Haine, La) (1995)': 'tt0113247',
#  'Shopping (1994)': 'tt0111173',
#  'City Hall (1996)': 'tt0115907',
#  'Bottle Rocket (1996)': 'tt0115734',
#  'Mr. Wrong (1996)': 'tt0117102',
#  'Unforgettable (1996)': 'tt0118040',
#  'Happy Gilmore (1996)': 'tt0116483',
#  'Bridges of Madison County, The (1995)': 'tt0112579',
#  'Nobody Loves Me (Keiner liebt mich) (1994)': 'tt0110251',
#  'Muppet Treasure Island (1996)': 'tt0117110',
#  'Catwalk (1996)': 'tt0112646',
#  'Headless Body in Topless Bar (1995)': 'tt0113276',
#  'Braveheart (1995)': 'tt0112573',
#  'Taxi Driver (1976)': 'tt0075314',
#  'Rumble in the Bronx (Hont faan kui) (1995)': 'tt0113326',
#  'Before and After (1996)': 'tt0115645',
#  "Margaret's Museum (1995)": 'tt0113774',
#  'Happiness Is in the Field (Bonheur est dans le pré, Le) (1995)': 'tt0112556',
#  'Anne Frank Remembered (1995)': 'tt0112373',
#  "Young Poisoner's Handbook, The (1995)": 'tt0115033',
#  'If Lucy Fell (1996)': 'tt0116606',
#  'Steal Big, Steal Little (1995)': 'tt0114536',
#  'Race the Sun (1996)': 'tt0117427',
#  'Boys of St. Vincent, The (1992)': 'tt0106473',
#  'Boomerang (1992)': 'tt0103859',
#  'Chungking Express (Chung Hing sam lam) (1994)': 'tt0109424',
#  "Star Maker, The (Uomo delle stelle, L') (1995)": 'tt0114808',
#  'Flirting With Disaster (1996)': 'tt0116324',
#  'NeverEnding Story III, The (1994)': 'tt0110647',
#  'Silences of the Palace, The (Saimt el Qusur) (1994)': 'tt0111055',
#  "Jupiter's Wife (1994)": 'tt0110217',
#  'Pie in the Sky (1996)': 'tt0114131',
#  'Angela (1995)': 'tt0112364',
#  'Frankie Starlight (1995)': 'tt0113107',
#  'Jade (1995)': 'tt0113451',
#  'Nueba Yol (1995)': 'tt0114015',
#  'Sonic Outlaws (1995)': 'tt0114500',
#  'Down Periscope (1996)': 'tt0116130',
#  'From the Journals of Jean Seberg (1995)': 'tt0113125',
#  'Man of the Year (1995)': 'tt0113756',
#  'Neon Bible, The (1995)': 'tt0113952',
#  'Target (1995)': 'tt0114618',
#  'Up Close and Personal (1996)': 'tt0118055',
#  'Birdcage, The (1996)': 'tt0115685',
#  'Gospa (1995)': 'tt0113200',
#  'Brothers McMullen, The (1995)': 'tt0112585',
#  'Bad Boys (1995)': 'tt0112442',
#  'Amazing Panda Adventure, The (1995)': 'tt0112342',
#  'Basketball Diaries, The (1995)': 'tt0112461',
#  'Awfully Big Adventure, An (1995)': 'tt0112427',
#  'Amateur (1994)': 'tt0109093',
#  'Apollo 13 (1995)': 'tt0112384',
#  'Rob Roy (1995)': 'tt0114287',
#  'Addiction, The (1995)': 'tt0112288',
#  'Batman Forever (1995)': 'tt0112462',
#  'Beauty of the Day (Belle de jour) (1967)': 'tt0061395',
#  'Beyond Rangoon (1995)': 'tt0112495',
#  'Blue in the Face (1995)': 'tt0112541',
#  'Canadian Bacon (1995)': 'tt0109370',
#  'Casper (1995)': 'tt0112642',
#  'Clockers (1995)': 'tt0112688',
#  'Congo (1995)': 'tt0112715',
#  'Crimson Tide (1995)': 'tt0112740',
#  'Crumb (1994)': 'tt0109508',
#  'Desperado (1995)': 'tt0112851',
#  'Devil in a Blue Dress (1995)': 'tt0112857',
#  'Die Hard: With a Vengeance (1995)': 'tt0112864',
#  'Doom Generation, The (1995)': 'tt0112887',
#  'Feast of July (1995)': 'tt0113044',
#  'First Knight (1995)': 'tt0113071',
#  'Free Willy 2: The Adventure Home (1995)': 'tt0113114',
#  'Hackers (1995)': 'tt0113243',
#  'Jeffrey (1995)': 'tt0113464',
#  'Johnny Mnemonic (1995)': 'tt0113481',
#  'Judge Dredd (1995)': 'tt0113492',
#  'Jury Duty (1995)': 'tt0113500',
#  'Kids (1995)': 'tt0113540',
#  'Living in Oblivion (1995)': 'tt0113677',
#  'Lord of Illusions (1995)': 'tt0113690',
#  'Love & Human Remains (1993)': 'tt0107447',
#  'Mad Love (1995)': 'tt0113729',
#  'Mallrats (1995)': 'tt0113749',
#  'Mighty Morphin Power Rangers: The Movie (1995)': 'tt0113820',
#  'Moonlight and Valentino (1995)': 'tt0113851',
#  'Mute Witness (1994)': 'tt0110604',
#  'Nadja (1994)': 'tt0110620',
#  'Net, The (1995)': 'tt0113957',
#  'Nine Months (1995)': 'tt0113986',
#  'Party Girl (1995)': 'tt0114095',
#  'Prophecy, The (1995)': 'tt0114194',
#  'Reckless (1995)': 'tt0114241',
#  'Safe (1995)': 'tt0114323',
#  'Scarlet Letter, The (1995)': 'tt0114345',
#  'The Show (1995)': 'tt0114435',
#  'Showgirls (1995)': 'tt0114436',
#  'Smoke (1995)': 'tt0114478',
#  'Something to Talk About (1995)': 'tt0114496',
#  'Species (1995)': 'tt0114508',
#  'Stars Fell on Henrietta, The (1995)': 'tt0114534',
#  'Strange Days (1995)': 'tt0114558',
#  'Tie That Binds, The (1995)': 'tt0114666',
#  'Three Wishes (1995)': 'tt0114663',
#  'Total Eclipse (1995)': 'tt0114702',
#  'To Wong Foo, Thanks for Everything! Julie Newmar (1995)': 'tt0114682',
#  'Under Siege 2: Dark Territory (1995)': 'tt0114781',
#  'Unstrung Heroes (1995)': 'tt0114798',
#  'Unzipped (1995)': 'tt0114805',
#  'Walk in the Clouds, A (1995)': 'tt0114887',
#  'Waterworld (1995)': 'tt0114898',
#  "White Man's Burden (1995)": 'tt0114928',
#  'Wild Bill (1995)': 'tt0114938',
#  'Browning Version, The (1994)': 'tt0109340',
#  'Bushwhacked (1995)': 'tt0112602',
#  'Burnt by the Sun (Utomlyonnye solntsem) (1994)': 'tt0111579',
#  'Before the Rain (Pred dozhdot) (1994)': 'tt0110882',
#  'Before Sunrise (1995)': 'tt0112471',
#  'Billy Madison (1995)': 'tt0112508',
#  'Babysitter, The (1995)': 'tt0112438',
#  'Boys on the Side (1995)': 'tt0112571',
#  'Cure, The (1995)': 'tt0112757',
#  'Castle Freak (1995)': 'tt0112643',
#  'Circle of Friends (1995)': 'tt0112679',
#  'Clerks (1994)': 'tt0109445',
#  'Don Juan DeMarco (1995)': 'tt0112883',
#  'Disclosure (1994)': 'tt0109635',
#  'Dream Man (1995)': 'tt0112899',
#  'Drop Zone (1994)': 'tt0109676',
#  'Destiny Turns on the Radio (1995)': 'tt0112854',
#  'Death and the Maiden (1994)': 'tt0109579',
#  'Dolores Claiborne (1995)': 'tt0109642',
#  'Dumb & Dumber (Dumb and Dumber) (1994)': 'tt0109686',
#  'Eat Drink Man Woman (Yin shi nan nu) (1994)': 'tt0111797',
#  'Exotica (1994)': 'tt0109759',
#  'Exit to Eden (1994)': 'tt0109758',
#  'Ed Wood (1994)': 'tt0109707',
#  'French Kiss (1995)': 'tt0113117',
#  'Forget Paris (1995)': 'tt0113097',
#  'Far From Home: The Adventures of Yellow Dog (1995)': 'tt0113028',
#  'Goofy Movie, A (1995)': 'tt0113198',
#  'Hideaway (1995)': 'tt0113303',
#  'Fluke (1995)': 'tt0113089',
#  'Farinelli: il castrato (1994)': 'tt0109771',
#  'Gordy (1995)': 'tt0113199',
#  'Gumby: The Movie (1995)': 'tt0113234',
#  'The Glass Shield (1994)': 'tt0109906',
#  'Hoop Dreams (1994)': 'tt0110057',
#  'Heavenly Creatures (1994)': 'tt0110005',
#  'Houseguest (1994)': 'tt0110066',
#  'Immortal Beloved (1994)': 'tt0110116',
#  'Heavyweights (Heavy Weights) (1995)': 'tt0110006',
#  'Hunted, The (1995)': 'tt0113360',
#  'I.Q. (1994)': 'tt0110099',
#  'Interview with the Vampire: The Vampire Chronicles (1994)': 'tt0110148',
#  'Jefferson in Paris (1995)': 'tt0113463',
#  'Jerky Boys, The (1995)': 'tt0110189',
#  'Junior (1994)': 'tt0110216',
#  'Just Cause (1995)': 'tt0113501',
#  "Kid in King Arthur's Court, A (1995)": 'tt0113538',
#  'Kiss of Death (1995)': 'tt0113552',
#  'Star Wars: Episode IV - A New Hope (1977)': 'tt0076759',
#  'Little Women (1994)': 'tt0110367',
#  'Little Princess, A (1995)': 'tt0113670',
#  'Ladybird Ladybird (1994)': 'tt0110296',
#  "Enfer, L' (1994)": 'tt0109731',
#  'Like Water for Chocolate (Como agua para chocolate) (1992)': 'tt0103994',
#  'Legends of the Fall (1994)': 'tt0110322',
#  'Major Payne (1995)': 'tt0110443',
#  'Little Odessa (1994)': 'tt0110365',
#  'My Crazy Life (Mi vida loca) (1993)': 'tt0107566',
#  'Love Affair (1994)': 'tt0110391',
#  'Losing Isaiah (1995)': 'tt0113691',
#  'Madness of King George, The (1994)': 'tt0110428',
#  "Mary Shelley's Frankenstein (Frankenstein) (1994)": 'tt0109836',
#  'Man of the House (1995)': 'tt0113755',
#  'Mixed Nuts (1994)': 'tt0110538',
#  'Milk Money (1994)': 'tt0110516',
#  'Miracle on 34th Street (1994)': 'tt0110527',
#  'Miami Rhapsody (1995)': 'tt0113808',
#  'My Family (1995)': 'tt0113896',
#  'Murder in the First (1995)': 'tt0113870',
#  "Nobody's Fool (1994)": 'tt0110684',
#  'Nell (1994)': 'tt0110638',
#  'New Jersey Drive (1995)': 'tt0113967',
#  'New York Cop (Nyû Yôku no koppu) (1993)': 'tt0117169',
#  'Beyond Bedlam (1993)': 'tt0106402',
#  'Nemesis 2: Nebula (1995)': 'tt0113948',
#  'Nina Takes a Lover (1994)': 'tt0110671',
#  'Natural Born Killers (1994)': 'tt0110632',
#  'Only You (1994)': 'tt0110737',
#  'Once Were Warriors (1994)': 'tt0110729',
#  'Outbreak (1995)': 'tt0114069',
#  'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)': 'tt0110413',
#  'Perez Family, The (1995)': 'tt0114113',
#  "Pyromaniac's Love Story, A (1995)": 'tt0114210',
#  'Pulp Fiction (1994)': 'tt0110912',
#  'Panther (1995)': 'tt0114084',
#  'Pushing Hands (Tui shou) (1992)': 'tt0105652',
#  'Priest (1994)': 'tt0110889',
#  'Quiz Show (1994)': 'tt0110932',
#  'Picture Bride (Bijo photo) (1994)': 'tt0114129',
#  'Queen Margot (Reine Margot, La) (1994)': 'tt0110963',
#  'Quick and the Dead, The (1995)': 'tt0114214',
#  'Roommates (1995)': 'tt0114296',
#  'Ready to Wear (Pret-A-Porter) (1994)': 'tt0110907',
#  'Three Colors: Red (Trois couleurs: Rouge) (1994)': 'tt0111495',
#  'Three Colors: Blue (Trois couleurs: Bleu) (1993)': 'tt0108394',
#  'Three Colors: White (Trzy kolory: Bialy) (1994)': 'tt0111507',
#  'Red Firecracker, Green Firecracker (Pao Da Shuang Deng) (1994)': 'tt0110769',
#  'Rent-a-Kid (1995)': 'tt0114268',
#  'Relative Fear (1994)': 'tt0110965',
#  'Stuart Saves His Family (1995)': 'tt0114571',
#  'Swan Princess, The (1994)': 'tt0111333',
#  'Secret of Roan Inish, The (1994)': 'tt0111112',
#  'Specialist, The (1994)': 'tt0111255',
#  'Stargate (1994)': 'tt0111282',
#  'Santa Clause, The (1994)': 'tt0111070',
#  'Shawshank Redemption, The (1994)': 'tt0111161',
#  'Shallow Grave (1994)': 'tt0111149',
#  'Suture (1993)': 'tt0108260',
#  'Strawberry and Chocolate (Fresa y chocolate) (1993)': 'tt0106966',
#  'Swimming with Sharks (1995)': 'tt0114594',
#  'Sum of Us, The (1994)': 'tt0111309',
#  "National Lampoon's Senior Trip (1995)": 'tt0113936',
#  'To Live (Huozhe) (1994)': 'tt0110081',
#  'Tank Girl (1995)': 'tt0114614',
#  'Tales from the Crypt Presents: Demon Knight (1995)': 'tt0114608',
#  'Star Trek: Generations (1994)': 'tt0111280',
#  'Tales from the Hood (1995)': 'tt0114609',
#  'Tom & Viv (1994)': 'tt0111454',
#  'Village of the Damned (1995)': 'tt0114852',
#  'Tommy Boy (1995)': 'tt0114694',
#  'Vanya on 42nd Street (1994)': 'tt0111590',
#  'Underneath (1995)': 'tt0114788',
#  'Walking Dead, The (1995)': 'tt0114888',
#  "What's Eating Gilbert Grape (1993)": 'tt0108550',
#  'Virtuosity (1995)': 'tt0114857',
#  'While You Were Sleeping (1995)': 'tt0114924',
#  'War, The (1994)': 'tt0111667',
#  'Double Happiness (1994)': 'tt0109655',
#  "Muriel's Wedding (1994)": 'tt0110598',
#  'Baby-Sitters Club, The (1995)': 'tt0112435',
#  'Ace Ventura: Pet Detective (1994)': 'tt0109040',
#  'Adventures of Priscilla, Queen of the Desert, The (1994)': 'tt0109045',
#  'Backbeat (1993)': 'tt0106339',
#  'Bitter Moon (1992)': 'tt0104779',
#  'Bullets Over Broadway (1994)': 'tt0109348',
#  'Clear and Present Danger (1994)': 'tt0109444',
#  'Client, The (1994)': 'tt0109446',
#  'Corrina, Corrina (1994)': 'tt0109484',
#  'Crooklyn (1994)': 'tt0109504',
#  'Crow, The (1994)': 'tt0109506',
#  'Cobb (1994)': 'tt0109450',
#  'Flintstones, The (1994)': 'tt0109813',
#  'Forrest Gump (1994)': 'tt0109830',
#  'Four Weddings and a Funeral (1994)': 'tt0109831',
#  'Higher Learning (1995)': 'tt0113305',
#  'I Like It Like That (1994)': 'tt0110091',
#  'I Love Trouble (1994)': 'tt0110093',
#  'It Could Happen to You (1994)': 'tt0110167',
#  'Jungle Book, The (1994)': 'tt0110213',
#  'Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993)': 'tt0107472',
#  'Lion King, The (1994)': 'tt0110357',
#  'Little Buddha (1993)': 'tt0107426',
#  "Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)": 'tt0111686',
#  'Mask, The (1994)': 'tt0110475',
#  'Maverick (1994)': 'tt0110478',
#  'Mrs. Parker and the Vicious Circle (1994)': 'tt0110588',
#  'Naked Gun 33 1/3: The Final Insult (1994)': 'tt0110622',
#  'Paper, The (1994)': 'tt0110771',
#  'Reality Bites (1994)': 'tt0110950',
#  'Red Rock West (1992)': 'tt0105226',
#  'Richie Rich (1994)': 'tt0110989',
#  'Safe Passage (1994)': 'tt0111054',
#  'River Wild, The (1994)': 'tt0110997',
#  'Speed (1994)': 'tt0111257',
#  'Speechless (1994)': 'tt0111256',
#  'Timecop (1994)': 'tt0111438',
#  'True Lies (1994)': 'tt0111503',
#  'When a Man Loves a Woman (1994)': 'tt0111693',
#  'Wolf (1994)': 'tt0111742',
#  'Wyatt Earp (1994)': 'tt0111756',
#  'Bad Company (1995)': 'tt0112443',
#  'Man of No Importance, A (1994)': 'tt0110455',
#  'S.F.W. (1994)': 'tt0111048',
#  'Low Down Dirty Shame, A (1994)': 'tt0110399',
#  'Boys Life (1995)': 'tt0112570',
#  'Colonel Chabert, Le (1994)': 'tt0109454',
#  "Jason's Lyric (1994)": 'tt0110186',
#  'Secret Adventures of Tom Thumb, The (1993)': 'tt0108069',
#  'Street Fighter (1994)': 'tt0111301',
#  'Coldblooded (1995)': 'tt0112702',
#  'Desert Winds (1995)': 'tt0112849',
#  'Fall Time (1995)': 'tt0113014',
#  'Fear, The (1995)': 'tt0113043',
#  'Frank and Ollie (1995)': 'tt0113104',
#  'Girl in the Cadillac (1995)': 'tt0113173',
#  'Homage (1995)': 'tt0113319',
#  'Mirage (1995)': 'tt0113827',
#  'Open Season (1996)': 'tt0114047',
#  'Two Crimes (Dos crímenes) (1995)': 'tt0112889',
#  'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)': 'tt0110027',
#  'Federal Hill (1994)': 'tt0109785',
#  'In the Mouth of Madness (1995)': 'tt0113409',
#  '8 Seconds (1994)': 'tt0109021',
#  'Above the Rim (1994)': 'tt0109035',
#  'Addams Family Values (1993)': 'tt0106220',
#  'Martin Lawrence: You So Crazy (1994)': 'tt0111804',
#  'Age of Innocence, The (1993)': 'tt0106226',
#  'Airheads (1994)': 'tt0109068',
#  'Air Up There, The (1994)': 'tt0109067',
#  'Another Stakeout (1993)': 'tt0106292',
#  'Bad Girls (1994)': 'tt0109198',
#  'Barcelona (1994)': 'tt0109219',
#  'Being Human (1993)': 'tt0106379',
#  'Beverly Hillbillies, The (1993)': 'tt0106400',
#  'Beverly Hills Cop III (1994)': 'tt0109254',
#  'Black Beauty (1994)': 'tt0109279',
#  'Blink (1994)': 'tt0109297',
#  'Blown Away (1994)': 'tt0109303',
#  'Blue Chips (1994)': 'tt0109305',
#  'Blue Sky (1994)': 'tt0109306',
#  'Body Snatchers (1993)': 'tt0106452',
#  'Boxing Helena (1993)': 'tt0106471',
#  'Bronx Tale, A (1993)': 'tt0106489',
#  'Cabin Boy (1994)': 'tt0109361',
#  'Calendar Girl (1993)': 'tt0106505',
#  "Carlito's Way (1993)": 'tt0106519',
#  "City Slickers II: The Legend of Curly's Gold (1994)": 'tt0109439',
#  'Clean Slate (1994)': 'tt0109443',
#  'Cliffhanger (1993)': 'tt0106582',
#  'Coneheads (1993)': 'tt0106598',
#  'Color of Night (1994)': 'tt0109456',
#  'Cops and Robbersons (1994)': 'tt0109480',
#  'Cowboy Way, The (1994)': 'tt0109493',
#  'Dangerous Game (1993)': 'tt0106660',
#  'Dave (1993)': 'tt0106673',
#  'Dazed and Confused (1993)': 'tt0106677',
#  'Demolition Man (1993)': 'tt0106697',
#  'Endless Summer 2, The (1994)': 'tt0109729',
#  'Even Cowgirls Get the Blues (1993)': 'tt0106834',
#  'Fatal Instinct (1993)': 'tt0106873',
#  'Farewell My Concubine (Ba wang bie ji) (1993)': 'tt0106332',
#  'Favor, The (1994)': 'tt0109783',
#  'Fearless (1993)': 'tt0106881',
#  'Fear of a Black Hat (1994)': 'tt0106880',
#  'With Honors (1994)': 'tt0111732',
#  'Flesh and Bone (1993)': 'tt0106926',
#  "Widows' Peak (1994)": 'tt0111712',
#  'For Love or Money (1993)': 'tt0106941',
#  'Firm, The (1993)': 'tt0106918',
#  'Free Willy (1993)': 'tt0106965',
#  'Fresh (1994)': 'tt0109842',
#  'Fugitive, The (1993)': 'tt0106977',
#  'Geronimo: An American Legend (1993)': 'tt0107004',
#  'Getaway, The (1994)': 'tt0109890',
#  'Getting Even with Dad (1994)': 'tt0109891',
#  'Go Fish (1994)': 'tt0109913',
#  'Good Man in Africa, A (1994)': 'tt0109920',
#  'Guilty as Sin (1993)': 'tt0107057',
#  'Hard Target (1993)': 'tt0107076',
#  'Heaven & Earth (1993)': 'tt0107096',
#  'Hot Shots! Part Deux (1993)': 'tt0107144',
#  'Live Nude Girls (1995)': 'tt0113674',
#  'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)': 'tt0112966',
#  'House of the Spirits, The (1993)': 'tt0107151',
#  'House Party 3 (1994)': 'tt0110064',
#  'Hudsucker Proxy, The (1994)': 'tt0110074',
#  "I'll Do Anything (1994)": 'tt0110097',
#  'In the Army Now (1994)': 'tt0110123',
#  'In the Line of Fire (1993)': 'tt0107206',
#  'In the Name of the Father (1993)': 'tt0107207',
#  'Inkwell, The (1994)': 'tt0110137',
#  "What's Love Got to Do with It? (1993)": 'tt0108551',
#  'Jimmy Hollywood (1994)': 'tt0110197',
#  'Judgment Night (1993)': 'tt0107286',
#  'Jurassic Park (1993)': 'tt0107290',
#  'Kalifornia (1993)': 'tt0107302',
#  'Killing Zoe (1994)': 'tt0110265',
#  'King of the Hill (1993)': 'tt0107322',
#  'Lassie (1994)': 'tt0110305',
#  'Last Action Hero (1993)': 'tt0107362',
#  'Life with Mikey (1993)': 'tt0107413',
#  'Lightning Jack (1994)': 'tt0110353',
#  'M. Butterfly (1993)': 'tt0107468',
#  'Made in America (1993)': 'tt0107478',
#  'Malice (1993)': 'tt0107497',
#  'Man Without a Face, The (1993)': 'tt0107501',
#  'Manhattan Murder Mystery (1993)': 'tt0107507',
#  'Menace II Society (1993)': 'tt0107554',
#  'Executive Decision (1996)': 'tt0116253',
#  'In the Realm of the Senses (Ai no corrida) (1976)': 'tt0074102',
#  'What Happened Was... (1994)': 'tt0111689',
#  'Much Ado About Nothing (1993)': 'tt0107616',
#  'Mr. Jones (1993)': 'tt0107611',
#  'Mr. Wonderful (1993)': 'tt0107613',
#  'Mrs. Doubtfire (1993)': 'tt0107614',
#  'Naked (1993)': 'tt0107653',
#  'Next Karate Kid, The (1994)': 'tt0110657',
#  'New Age, The (1994)': 'tt0110649',
#  'No Escape (1994)': 'tt0110678',
#  'North (1994)': 'tt0110687',
#  'Orlando (1992)': 'tt0107756',
#  'Perfect World, A (1993)': 'tt0107808',
#  'Philadelphia (1993)': 'tt0107818',
#  'Piano, The (1993)': 'tt0107822',
#  'Poetic Justice (1993)': 'tt0107840',
#  'Program, The (1993)': 'tt0107889',
#  'Puppet Masters, The (1994)': 'tt0111003',
#  'Radioland Murders (1994)': 'tt0110939',
#  'Ref, The (1994)': 'tt0110955',
#  'Remains of the Day, The (1993)': 'tt0107943',
#  'Renaissance Man (1994)': 'tt0110971',
#  'Rising Sun (1993)': 'tt0107969',
#  'Road to Wellville, The (1994)': 'tt0111001',
#  'RoboCop 3 (1993)': 'tt0107978',
#  'Robin Hood: Men in Tights (1993)': 'tt0107977',
#  'Romeo Is Bleeding (1993)': 'tt0107983',
#  'Romper Stomper (1992)': 'tt0105275',
#  'Ruby in Paradise (1993)': 'tt0108000',
#  'Rudy (1993)': 'tt0108002',
#  'Saint of Fort Washington, The (1993)': 'tt0108026',
#  'Savage Nights (Nuits fauves, Les) (1992)': 'tt0105032',
#  "Schindler's List (1993)": 'tt0108052',
#  'Scout, The (1994)': 'tt0111094',
#  'Searching for Bobby Fischer (1993)': 'tt0108065',
#  'Second Best (1994)': 'tt0111102',
#  'Secret Garden, The (1993)': 'tt0108071',
#  'Serial Mom (1994)': 'tt0111127',
#  'Shadow, The (1994)': 'tt0111143',
#  'Shadowlands (1993)': 'tt0108101',
#  'Short Cuts (1993)': 'tt0108122',
#  'Simple Twist of Fate, A (1994)': 'tt0111194',
#  'Sirens (1994)': 'tt0111201',
#  'Six Degrees of Separation (1993)': 'tt0108149',
#  'Sleepless in Seattle (1993)': 'tt0108160',
#  'Sliver (1993)': 'tt0108162',
#  'Son in Law (1993)': 'tt0108186',
#  'So I Married an Axe Murderer (1993)': 'tt0108174',
#  'Striking Distance (1993)': 'tt0108238',
#  'Super Mario Bros. (1993)': 'tt0108255',
#  'Surviving the Game (1994)': 'tt0111323',
#  'Terminal Velocity (1994)': 'tt0111400',
#  'Thirty-Two Short Films About Glenn Gould (1993)': 'tt0108328',
#  'Threesome (1994)': 'tt0111418',
#  'Nightmare Before Christmas, The (1993)': 'tt0107688',
#  'Three Musketeers, The (1993)': 'tt0108333',
#  'Tombstone (1993)': 'tt0108358',
#  'Trial by Jury (1994)': 'tt0111488',
#  'True Romance (1993)': 'tt0108399',
#  'War Room, The (1993)': 'tt0108515',
#  'Pagemaster, The (1994)': 'tt0110763',
#  'Paris, France (1993)': 'tt0107779',
#  'Beans of Egypt, Maine, The (1994)': 'tt0109226',
#  'Killer (Bulletproof Heart) (1994)': 'tt0110259',
#  'Welcome to the Dollhouse (1995)': 'tt0114906',
#  'Germinal (1993)': 'tt0107002',
#  'Chasers (1994)': 'tt0109403',
#  'Cronos (1993)': 'tt0104029',
#  'Naked in New York (1994)': 'tt0110623',
#  'Kika (1993)': 'tt0107315',
#  'Bhaji on the Beach (1993)': 'tt0106408',
#  'Little Big League (1994)': 'tt0110363',
#  'Slingshot, The (Kådisbellan) (1993)': 'tt0107349',
#  'Wedding Gift, The (1994)': 'tt0111709',
#  'Foreign Student (1994)': 'tt0109828',
#  'Ciao, Professore! (Io speriamo che me la cavo) (1992)': 'tt0107225',
#  'Spanking the Monkey (1994)': 'tt0111252',
#  'Little Rascals, The (1994)': 'tt0110366',
#  'Fausto (1993)': 'tt0106878',
#  'Andre (1994)': 'tt0109120',
#  'Escort, The (Scorta, La) (1993)': 'tt0108059',
#  'Princess Caraboo (1994)': 'tt0110892',
#  'Celluloid Closet, The (1995)': 'tt0112651',
#  'Métisse (Café au Lait) (1993)': 'tt0107642',
#  'Dear Diary (Caro Diario) (1994)': 'tt0109382',
#  "I Don't Want to Talk About It (De eso no se habla) (1993)": 'tt0106678',
#  'Brady Bunch Movie, The (1995)': 'tt0112572',
#  'Home Alone (1990)': 'tt0099785',
#  'Ghost (1990)': 'tt0099653',
#  'Aladdin (1992)': 'tt0103639',
#  'Terminator 2: Judgment Day (1991)': 'tt0103064',
#  'Dances with Wolves (1990)': 'tt0099348',
#  'Tough and Deadly (1995)': 'tt0114706',
#  'Silence of the Lambs, The (1991)': 'tt0102926',
#  'Snow White and the Seven Dwarfs (1937)': 'tt0029583',
#  'Beauty and the Beast (1991)': 'tt0101414',
#  'Pinocchio (1940)': 'tt0032910',
#  'Pretty Woman (1990)': 'tt0100405',
#  'Window to Paris (Okno v Parizh) (1994)': 'tt0110719',
#  'Wild Bunch, The (1969)': 'tt0065214',
#  'Love and a .45 (1994)': 'tt0110395',
#  "Wooden Man's Bride, The (Yan shen) (1994)": 'tt0111752',
#  'Great Day in Harlem, A (1994)': 'tt0109934',
#  'Bye Bye, Love (1995)': 'tt0112606',
#  'One Fine Day (1996)': 'tt0117247',
#  'Candyman: Farewell to the Flesh (1995)': 'tt0112625',
#  'Century (1993)': 'tt0106537',
#  'Fargo (1996)': 'tt0116282',
#  'Homeward Bound II: Lost in San Francisco (1996)': 'tt0116552',
#  'Hellraiser: Bloodline (1996)': 'tt0116514',
#  'Pallbearer, The (1996)': 'tt0117283',
#  'Jane Eyre (1996)': 'tt0116684',
#  'Loaded (1994)': 'tt0110374',
#  'Bread and Chocolate (Pane e cioccolata) (1973)': 'tt0070506',
#  'Aristocats, The (1970)': 'tt0065421',
#  'Flower of My Secret, The (La flor de mi secreto) (1995)': 'tt0113083',
#  'Two Much (1995)': 'tt0118001',
#  'Ed (1996)': 'tt0116165',
#  'Scream of Stone (Cerro Torre: Schrei aus Stein) (1991)': 'tt0102855',
#  'My Favorite Season (1993)': 'tt0107471',
#  'Modern Affair, A (1995)': 'tt0113839',
#  'Thin Line Between Love and Hate, A (1996)': 'tt0117891',
#  'Last Supper, The (1995)': 'tt0113613',
#  'Primal Fear (1996)': 'tt0117381',
#  'Rude (1995)': 'tt0114305',
#  'Carried Away (1996)': 'tt0115837',
#  'All Dogs Go to Heaven 2 (1996)': 'tt0115509',
#  'Land and Freedom (Tierra y libertad) (1995)': 'tt0114671',
#  'Denise Calls Up (1995)': 'tt0112844',
#  'Theodore Rex (1995)': 'tt0114658',
#  'Family Thing, A (1996)': 'tt0116275',
#  'Frisk (1995)': 'tt0113122',
#  'Sgt. Bilko (1996)': 'tt0117608',
#  'Jack and Sarah (1995)': 'tt0113448',
#  'Girl 6 (1996)': 'tt0116414',
#  'Diabolique (1996)': 'tt0116095',
#  'Little Indian, Big City (Un indien dans la ville) (1994)': 'tt0111543',
#  'Roula (1995)': 'tt0117517',
#  'Nelly & Monsieur Arnaud (1995)': 'tt0113947',
#  'Courage Under Fire (1996)': 'tt0115956',
#  'Mission: Impossible (1996)': 'tt0117060',
#  'Cold Fever (Á köldum klaka) (1995)': 'tt0109028',
#  'Moll Flanders (1996)': 'tt0117071',
#  'Superweib, Das (1996)': 'tt0117788',
#  '301, 302 (301/302) (1995)': 'tt0112257',
#  'Dragonheart (1996)': 'tt0116136',
#  'And Nobody Weeps for Me (Und keiner weint mir nach) (1996)': 'tt0118026',
#  "My Mother's Courage (Mutters Courage) (1995)": 'tt0117117',
#  'Eddie (1996)': 'tt0116168',
#  'Yankee Zulu (1994)': 'tt0111787',
#  "Billy's Holiday (1995)": 'tt0112509',
#  'August (1996)': 'tt0115591',
#  'James and the Giant Peach (1996)': 'tt0116683',
#  'Fear (1996)': 'tt0116287',
#  'Kids in the Hall: Brain Candy (1996)': 'tt0116768',
#  'Faithful (1996)': 'tt0116269',
#  'Underground (1995)': 'tt0114787',
#  'All Things Fair (Lust och fägring stor) (1995)': 'tt0113720',
#  'Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996)': 'tt0112536',
#  'Song of the Little Road (Pather Panchali) (1955)': 'tt0048473',
#  'World of Apu, The (Apur Sansar) (1959)': 'tt0052572',
#  'Mystery Science Theater 3000: The Movie (1996)': 'tt0117128',
#  'Tarantella (1995)': 'tt0114616',
#  'Space Jam (1996)': 'tt0117705',
#  'Barbarella (1968)': 'tt0062711',
#  'Hostile Intentions (1994)': 'tt0110061',
#  'They Bite (1996)': 'tt0140614',
#  'Some Folks Call It a Sling Blade (1993)': 'tt0108181',
#  'Run of the Country, The (1995)': 'tt0114307',
#  'Tigrero: A Film That Was Never Made (1994)': 'tt0111430',
#  "Eye of Vichy, The (Oeil de Vichy, L') (1993)": 'tt0107727',
#  'Windows (1980)': 'tt0081759',
#  "It's My Party (1996)": 'tt0113443',
#  'Country Life (1994)': 'tt0109491',
#  'Operation Dumbo Drop (1995)': 'tt0114048',
#  'Promise, The (Versprechen, Das) (1995)': 'tt0111613',
#  'Mrs. Winterbourne (1996)': 'tt0117104',
#  'Solo (1996)': 'tt0117688',
#  'Under the Domim Tree (Etz Hadomim Tafus) (1994)': 'tt0109751',
#  'Substitute, The (1996)': 'tt0117774',
#  'True Crime (1996)': 'tt0114736',
#  'Butterfly Kiss (1995)': 'tt0112604',
#  'Feeling Minnesota (1996)': 'tt0116289',
#  'Delta of Venus (1995)': 'tt0109593',
#  'To Cross the Rubicon (1991)': 'tt0103095',
#  'Angus (1995)': 'tt0112368',
#  'Daens (1992)': 'tt0104046',
#  'Faces (1968)': 'tt0062952',
#  'Boys (1996)': 'tt0115742',
#  'Quest, The (1996)': 'tt0117420',
#  'Cosi (1996)': 'tt0115951',
#  'Sunset Park (1996)': 'tt0117784',
#  'Mulholland Falls (1996)': 'tt0117107',
#  'Truth About Cats & Dogs, The (1996)': 'tt0117979',
#  'Celtic Pride (1996)': 'tt0115851',
#  'Flipper (1996)': 'tt0116322',
#  'Captives (1994)': 'tt0109374',
#  'Of Love and Shadows (1994)': 'tt0110712',
#  'Dead Man (1995)': 'tt0112817',
#  'Horseman on the Roof, The (Hussard sur le toit, Le) (1995)': 'tt0113362',
#  'Switchblade Sisters (1975)': 'tt0073778',
#  'Mouth to Mouth (Boca a boca) (1995)': 'tt0112546',
#  'Visitors, The (Visiteurs, Les) (1993)': 'tt0108500',
#  'Multiplicity (1996)': 'tt0117108',
#  'Halfmoon (Paul Bowles - Halbmond) (1995)': 'tt0114103',
#  'Haunted World of Edward D. Wood Jr., The (1996)': 'tt0113270',
#  'Craft, The (1996)': 'tt0115963',
#  'Great White Hype, The (1996)': 'tt0116448',
#  'Last Dance (1996)': 'tt0116827',
#  'War Stories (1995)': 'tt0114894',
#  'Cold Comfort Farm (1995)': 'tt0112701',
#  'Institute Benjamenta, or This Dream People Call Human Life (1995)': 'tt0113429',
#  "Heaven's Prisoners (1996)": 'tt0116508',
#  'Original Gangstas (1996)': 'tt0117260',
#  'Rock, The (1996)': 'tt0117500',
#  'Getting Away With Murder (1996)': 'tt0116405',
#  'Cemetery Man (Dellamorte Dellamore) (1994)': 'tt0109592',
#  'Twister (1996)': 'tt0117998',
#  'Barb Wire (1996)': 'tt0115624',
#  'Garçu, Le (1995)': 'tt0113145',
#  'Honey Moon (Honigmond) (1996)': 'tt0116559',
#  'Ghost in the Shell (Kôkaku kidôtai) (1995)': 'tt0113568',
#  'Thinner (1996)': 'tt0117894',
#  'Spy Hard (1996)': 'tt0117723',
#  'Brothers in Trouble (1995)': 'tt0112586',
#  'Wallace & Gromit: A Close Shave (1995)': 'tt0112691',
#  'Stupids, The (1996)': 'tt0117768',
#  'Arrival, The (1996)': 'tt0115571',
#  'Man from Down Under, The (1943)': 'tt0031612',
#  'Careful (1992)': 'tt0103926',
#  'Month by the Lake, A (1995)': 'tt0113849',
#  'Gold Diggers: The Secret of Bear Mountain (1995)': 'tt0113188',
#  'Carmen Miranda: Bananas Is My Business (1994)': 'tt0109381',
#  'Ashes of Time (Dung che sai duk) (1994)': 'tt0109688',
#  'Jar, The (Khomreh) (1992)': 'tt0104606',
#  'Maya Lin: A Strong Clear Vision (1994)': 'tt0110480',
#  'Stalingrad (1993)': 'tt0108211',
#  'Phantom, The (1996)': 'tt0117331',
#  'Striptease (1996)': 'tt0117765',
#  'Last of the High Kings, The (a.k.a. Summer Fling) (1996)': 'tt0116833',
#  'Heavy (1995)': 'tt0113280',
#  'Jack (1996)': 'tt0116669',
#  'I Shot Andy Warhol (1996)': 'tt0116594',
#  'Grass Harp, The (1995)': 'tt0113211',
#  "Someone Else's America (1995)": 'tt0114494',
#  'Marlene Dietrich: Shadow and Light (1996)': 'tt0116992',
#  'Quartier Mozart (1992)': 'tt0105201',
#  'Touki Bouki (1973)': 'tt0070820',
#  'Spirits of the Dead (1968)': 'tt0063715',
#  'Babyfever (1994)': 'tt0109191',
#  "Pharaoh's Army (1995)": 'tt0114122',
#  'Trainspotting (1996)': 'tt0117951',
#  "'Til There Was You (1997)": 'tt0118523',
#  'Independence Day (a.k.a. ID4) (1996)': 'tt0116629',
#  'Stealing Beauty (1996)': 'tt0117737',
#  'Fan, The (1996)': 'tt0116277',
#  'Hunchback of Notre Dame, The (1996)': 'tt0116583',
#  'Cable Guy, The (1996)': 'tt0115798',
#  'Kingpin (1996)': 'tt0116778',
#  'Eraser (1996)': 'tt0116213',
#  'Nutty Professor, The (1996)': 'tt0117218',
#  'I, the Worst of All (Yo, la peor de todas) (1990)': 'tt0100990',
#  'Unforgettable Summer, An (Un été inoubliable) (1994)': 'tt0111546',
#  'Last Klezmer: Leopold Kozlowski, His Life and Music, The (1994)': 'tt0113610',
#  "My Life and Times With Antonin Artaud (En compagnie d'Antonin Artaud) (1993)": 'tt0106810',
#  'Midnight Dancers (Sibak) (1994)': 'tt0111180',
#  'Somebody to Love (1994)': 'tt0111237',
#  'Very Natural Thing, A (1974)': 'tt0072362',
#  'Old Lady Who Walked in the Sea, The (Vieille qui marchait dans la mer, La) (1991)': 'tt0103207',
#  'Daylight (1996)': 'tt0116040',
#  'Frighteners, The (1996)': 'tt0116365',
#  'Lone Star (1996)': 'tt0116905',
#  'Harriet the Spy (1996)': 'tt0116493',
#  'Phenomenon (1996)': 'tt0117333',
#  'Walking and Talking (1996)': 'tt0118113',
#  "She's the One (1996)": 'tt0117628',
#  'Time to Kill, A (1996)': 'tt0117913',
#  'American Buffalo (1996)': 'tt0115530',
#  'Rendezvous in Paris (Rendez-vous de Paris, Les) (1995)': 'tt0114266',
#  'Alaska (1996)': 'tt0115493',
#  'Fled (1996)': 'tt0116320',
#  'Kazaam (1996)': 'tt0116756',
#  'Magic Hunter (Büvös vadász) (1994)': 'tt0109356',
#  'Larger Than Life (1996)': 'tt0116823',
#  'Boy Called Hate, A (1995)': 'tt0112568',
#  'Power 98 (1996)': 'tt0114170',
#  'Two Deaths (1995)': 'tt0117999',
#  'Very Brady Sequel, A (1996)': 'tt0118073',
#  'Stefano Quantestorie (1993)': 'tt0108220',
#  'Death in the Garden (Mort en ce jardin, La) (1956)': 'tt0049521',
#  'Crude Oasis, The (1995)': 'tt0112746',
#  'Hedd Wyn (1992)': 'tt0104403',
#  'Collector, The (La collectionneuse) (1967)': 'tt0061495',
#  'Kaspar Hauser (1993)': 'tt0110246',
#  'Regular Guys (Echte Kerle) (1996)': 'tt0116164',
#  'Women Robbers (Diebinnen) (1995)': 'tt0112865',
#  'Convent, The (O Convento) (1995)': 'tt0112716',
#  'Adventures of Pinocchio, The (1996)': 'tt0115472',
#  "Joe's Apartment (1996)": 'tt0116707',
#  'First Wives Club, The (1996)': 'tt0116313',
#  'Stonewall (1995)': 'tt0114550',
#  'Ransom (1996)': 'tt0117438',
#  'High School High (1996)': 'tt0116531',
#  'Phat Beach (1996)': 'tt0117332',
#  'Foxfire (1996)': 'tt0116353',
#  'Chain Reaction (1996)': 'tt0115857',
#  'Matilda (1996)': 'tt0117008',
#  'Emma (1996)': 'tt0116191',
#  'Crow: City of Angels, The (1996)': 'tt0115986',
#  'House Arrest (1996)': 'tt0116571',
#  'Tales from the Crypt Presents: Bordello of Blood (1996)': 'tt0117826',
#  'Story of Xinghua, The (Xinghua san yue tian) (1994)': 'tt0108227',
#  'Day the Sun Turned Cold, The (Tianguo niezi) (1994)': 'tt0111424',
#  'Flirt (1995)': 'tt0113080',
#  'Big Squeeze, The (1996)': 'tt0115680',
#  'Spitfire Grill, The (1996)': 'tt0117718',
#  'Escape from L.A. (1996)': 'tt0116225',
#  'Cyclo (Xich lo) (1995)': 'tt0112767',
#  'Basquiat (1996)': 'tt0115632',
#  'Tin Cup (1996)': 'tt0117918',
#  'Dingo (1991)': 'tt0104109',
#  'Ballad of Narayama, The (Narayama Bushiko) (1958)': 'tt0051980',
#  'Every Other Weekend (Un week-end sur deux) (1990)': 'tt0100840',
#  'Mille bolle blu (1993)': 'tt0107575',
#  'Godfather, The (1972)': 'tt0068646',
#  'Hippie Revolution, The (1996)': 'tt0116536',
#  'Maybe, Maybe Not (Bewegte Mann, Der) (1994)': 'tt0109255',
#  'Supercop (Police Story 3: Supercop) (Jing cha gu shi III: Chao ji jing cha) (1992)': 'tt0104558',
#  'Manny & Lo (1996)': 'tt0116985',
#  'Wife, The (1995)': 'tt0114936',
#  'Small Faces (1996)': 'tt0114474',
#  'Bound (1996)': 'tt0115736',
#  'Carpool (1996)': 'tt0115836',
#  'Death in Brunswick (1991)': 'tt0101692',
#  'Kansas City (1996)': 'tt0116745',
#  "Gone Fishin' (1997)": 'tt0119214',
#  "Lover's Knot (1996)": 'tt0116934',
#  "Vive L'Amour (Ai qing wan sui) (1994)": 'tt0109066',
#  'Shadow of Angels (Schatten der Engel) (1976)': 'tt0075169',
#  'Killer: A Journal of Murder (1995)': 'tt0113542',
#  'Supercop 2 (Project S) (Chao ji ji hua) (1993)': 'tt0106544',
#  'Girls Town (1996)': 'tt0116418',
#  'Bye-Bye (1995)': 'tt0112607',
#  'Relic, The (1997)': 'tt0120004',
#  'Island of Dr. Moreau, The (1996)': 'tt0116654',
#  'First Kid (1996)': 'tt0116311',
#  'Trigger Effect, The (1996)': 'tt0117965',
#  'Sweet Nothing (1996)': 'tt0114592',
#  'Bogus (1996)': 'tt0115725',
#  'Bulletproof (1996)': 'tt0115783',
#  'Talk of Angels (1998)': 'tt0120271',
#  '1-900 (06) (1994)': 'tt0109001',
#  'Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995)': 'tt0113253',
#  'Twelfth Night (1996)': 'tt0117991',
#  'Mother Night (1996)': 'tt0117093',
#  'Liebelei (1933)': 'tt0024252',
#  'Venice/Venice (1992)': 'tt0105729',
#  'Wild Reeds (Les roseaux sauvages) (1994)': 'tt0111019',
#  'For Whom the Bell Tolls (1943)': 'tt0035896',
#  'Philadelphia Story, The (1940)': 'tt0032904',
#  'Funny Face (1957)': 'tt0050419',
#  'Vertigo (1958)': 'tt0052357',
#  'Rear Window (1954)': 'tt0047396',
#  'It Happened One Night (1934)': 'tt0025316',
#  'Gaslight (1944)': 'tt0036855',
#  'Gay Divorcee, The (1934)': 'tt0025164',
#  'Casablanca (1942)': 'tt0034583',
#  'Maltese Falcon, The (1941)': 'tt0033870',
#  'Sabrina (1954)': 'tt0047437',
#  'Roman Holiday (1953)': 'tt0046250',
#  'Little Princess, The (1939)': 'tt0031580',
#  'Meet Me in St. Louis (1944)': 'tt0037059',
#  'Wizard of Oz, The (1939)': 'tt0032138',
#  'Gone with the Wind (1939)': 'tt0031381',
#  'Citizen Kane (1941)': 'tt0033467',
#  '2001: A Space Odyssey (1968)': 'tt0062622',
#  'Women, The (1939)': 'tt0032143',
#  'Rebecca (1940)': 'tt0032976',
#  'Foreign Correspondent (1940)': 'tt0032484',
#  'Spellbound (1945)': 'tt0038109',
#  'Affair to Remember, An (1957)': 'tt0050105',
#  'To Catch a Thief (1955)': 'tt0048728',
#  'Ninotchka (1939)': 'tt0031725',
#  'Love in the Afternoon (1957)': 'tt0050658',
#  'Gigi (1958)': 'tt0051658',
#  'Reluctant Debutante, The (1958)': 'tt0052126',
#  'Adventures of Robin Hood, The (1938)': 'tt0029843',
#  'Mark of Zorro, The (1940)': 'tt0032762',
#  'Laura (1944)': 'tt0037008',
#  'Lost Horizon (1937)': 'tt0029162',
#  'Top Hat (1935)': 'tt0027125',
#  'To Be or Not to Be (1942)': 'tt0035446',
#  'My Man Godfrey (1936)': 'tt0028010',
#  'Giant (1956)': 'tt0049261',
#  'East of Eden (1955)': 'tt0048028',
#  'Thin Man, The (1934)': 'tt0025878',
#  'His Girl Friday (1940)': 'tt0032599',
#  'Around the World in 80 Days (1956)': 'tt0048960',
#  'Mr. Smith Goes to Washington (1939)': 'tt0031679',
#  'Bringing Up Baby (1938)': 'tt0029947',
#  'Penny Serenade (1941)': 'tt0034012',
#  'Lady of Burlesque (1943)': 'tt0036094',
#  'Of Human Bondage (1934)': 'tt0025586',
#  'Angel on My Shoulder (1946)': 'tt0038300',
#  'Little Lord Fauntleroy (1936)': 'tt0027893',
#  'They Made Me a Criminal (1939)': 'tt0032022',
#  '39 Steps, The (1935)': 'tt0026029',
#  'A Walk in the Sun (1945)': 'tt0038235',
#  'Outlaw, The (1943)': 'tt0036241',
#  'Night of the Living Dead (1968)': 'tt0063350',
#  'Beat the Devil (1953)': 'tt0046414',
#  'Cat on a Hot Tin Roof (1958)': 'tt0051459',
#  'Last Time I Saw Paris, The (1954)': 'tt0047162',
#  'Meet John Doe (1941)': 'tt0033891',
#  'Algiers (1938)': 'tt0029855',
#  'Something to Sing About (1937)': 'tt0029588',
#  'Farewell to Arms, A (1932)': 'tt0022879',
#  'Moonlight Murder (1936)': 'tt0027980',
#  'Nothing Personal (1995)': 'tt0114007',
#  'Dangerous Ground (1997)': 'tt0118927',
#  'Picnic (1955)': 'tt0048491',
#  'Madagascar Skin (1995)': 'tt0113730',
#  'Pompatus of Love, The (1996)': 'tt0117357',
#  'Small Wonders (1995)': 'tt0117669',
#  'Fly Away Home (1996)': 'tt0116329',
#  'Bliss (1997)': 'tt0118742',
#  'Grace of My Heart (1996)': 'tt0116442',
#  'Brother of Sleep (Schlafes Bruder) (1995)': 'tt0114354',
#  'Maximum Risk (1996)': 'tt0117011',
#  'Michael Collins (1996)': 'tt0117039',
#  "Rich Man's Wife, The (1996)": 'tt0117473',
#  'Infinity (1996)': 'tt0116635',
#  'Big Night (1996)': 'tt0115678',
#  'Last Man Standing (1996)': 'tt0116830',
#  'Caught (1996)': 'tt0115847',
#  'Set It Off (1996)': 'tt0117603',
#  '2 Days in the Valley (1996)': 'tt0115438',
#  'Curdled (1996)': 'tt0115994',
#  "Ed's Next Move (1996)": 'tt0116167',
#  'Extreme Measures (1996)': 'tt0116259',
#  'Glimmer Man, The (1996)': 'tt0116421',
#  'D3: The Mighty Ducks (1996)': 'tt0116000',
#  'Chamber, The (1996)': 'tt0115862',
#  'Apple Dumpling Gang, The (1975)': 'tt0072653',
#  'Davy Crockett, King of the Wild Frontier (1955)': 'tt0047977',
#  'Escape to Witch Mountain (1975)': 'tt0072951',
#  'Love Bug, The (1969)': 'tt0064603',
#  'Herbie Rides Again (1974)': 'tt0071607',
#  'Old Yeller (1957)': 'tt0050798',
#  'Homeward Bound: The Incredible Journey (1993)': 'tt0107131',
#  'That Darn Cat! (1965)': 'tt0059793',
#  '20,000 Leagues Under the Sea (1954)': 'tt0046672',
#  'Cool Runnings (1993)': 'tt0106611',
#  'Angels in the Outfield (1994)': 'tt0109127',
#  'Winnie the Pooh and the Blustery Day (1968)': 'tt0063819',
#  'Three Caballeros, The (1945)': 'tt0038166',
#  'Robin Hood: Prince of Thieves (1991)': 'tt0102798',
#  'Dumbo (1941)': 'tt0033563',
#  "Pete's Dragon (1977)": 'tt0076538',
#  'Bedknobs and Broomsticks (1971)': 'tt0066817',
#  'Freeway (1996)': 'tt0116361',
#  'Lawnmower Man, The (1992)': 'tt0104692',
#  'Unhook the Stars (1996)': 'tt0118044',
#  'Synthetic Pleasures (1995)': 'tt0114597',
#  'Secret Agent, The (1996)': 'tt0117582',
#  'Secrets & Lies (1996)': 'tt0117589',
#  'That Thing You Do! (1996)': 'tt0117887',
#  'To Gillian on Her 37th Birthday (1996)': 'tt0117924',
#  'Surviving Picasso (1996)': 'tt0117791',
#  'Love Is All There Is (1996)': 'tt0116928',
#  'Beautiful Thing (1996)': 'tt0115640',
#  'Long Kiss Goodnight, The (1996)': 'tt0116908',
#  'Ghost and the Darkness, The (1996)': 'tt0116409',
#  'Looking for Richard (1996)': 'tt0116913',
#  'Trees Lounge (1996)': 'tt0117958',
#  'Proprietor, The (1996)': 'tt0117400',
#  'Normal Life (1996)': 'tt0117202',
#  'Get on the Bus (1996)': 'tt0116404',
#  'Shadow Conspiracy (1997)': 'tt0120107',
#  'Jude (1996)': 'tt0116722',
#  'Everyone Says I Love You (1996)': 'tt0116242',
#  'Bitter Sugar (Azúcar amarga) (1996)': 'tt0115600',
#  "William Shakespeare's Romeo + Juliet (1996)": 'tt0117509',
#  'Swingers (1996)': 'tt0117802',
#  'Sleepers (1996)': 'tt0117665',
#  'Sunchaser, The (1996)': 'tt0117781',
#  'Johns (1996)': 'tt0116714',
#  'Shall We Dance (1937)': 'tt0029546',
#  'Damsel in Distress, A (1937)': 'tt0028757',
#  'Murder, My Sweet (1944)': 'tt0037101',
#  'For the Moment (1994)': 'tt0109823',
#  'Willy Wonka & the Chocolate Factory (1971)': 'tt0067992',
#  'Sexual Life of the Belgians, The (Vie sexuelle des Belges 1950-1978, La) (1994)': 'tt0111622',
#  'Sleeper (1973)': 'tt0070707',
#  'Bananas (1971)': 'tt0066808',
#  "Monty Python's Life of Brian (1979)": 'tt0079470',
#  'Candidate, The (1972)': 'tt0068334',
#  'Bonnie and Clyde (1967)': 'tt0061418',
#  'Old Man and the Sea, The (1958)': 'tt0052027',
#  'Dial M for Murder (1954)': 'tt0046912',
#  'Madame Butterfly (1995)': 'tt0113731',
#  'Reservoir Dogs (1992)': 'tt0105236',
#  "Weekend at Bernie's (1989)": 'tt0098627',
#  'Basic Instinct (1992)': 'tt0103772',
#  'Doors, The (1991)': 'tt0101761',
#  'Crying Game, The (1992)': 'tt0104036',
#  'Glengarry Glen Ross (1992)': 'tt0104348',
#  'Search for One-eye Jimmy, The (1996)': 'tt0117577',
#  'Christmas Carol, A (1938)': 'tt0029992',
#  'Days of Thunder (1990)': 'tt0099371',
#  'American Strays (1996)': 'tt0115531',
#  'Rebel Without a Cause (1955)': 'tt0048545',
#  'Children of the Corn IV: The Gathering (1996)': 'tt0115885',
#  'Leopard Son, The (1996)': 'tt0116859',
#  'Loser (1991)': 'tt0102336',
#  ...}

# %%
# Saving our movies list and display it after :
import pickle
with open('movie_names.pkl', 'wb') as f:
    pickle.dump(movie_names, f)

# %%
# Our Recommendation system building code : 
import pandas as pd
import numpy as np

from math import pow, sqrt
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from fuzzywuzzy import process

df12 = pd.read_csv("df_initial.csv", sep=',' )
df12= df12[~pd.isna(df12['movieId'])]
df12= df12[~pd.isna(df12['castId'])]
df12.drop_duplicates(inplace=True)

movieId_map = df12[['movieId', 'title']].drop_duplicates()
castId_map = df12[['castId', 'primaryName']].drop_duplicates()

movieIdMap = dict(zip(movieId_map['movieId'],movieId_map['title']))
castIdMap = dict(zip(castId_map['castId'],castId_map['primaryName']))

df12.drop(["title", "primaryName",  "imdbId",  "category"], axis=1, inplace=True)

df_pivot = pd.DataFrame(df12.groupby(['movieId'])['castId'].apply(list))
df_pivot['castId'] = df_pivot.apply(lambda row: ' '.join(row['castId']) , axis=1)
movieIds = list(df_pivot.index)
castIds = list(df_pivot['castId'])
vectorizer = CountVectorizer().fit_transform(castIds)
vectors = vectorizer.toarray()

# Caluclate the cosine similarities
csim = cosine_similarity(vectors)

# finally save the cosine similarities which will only be loaded in app at the beginning
with open('cosines.pkl', 'wb') as f:
    pickle.dump(csim, f)
# Out:
# /usr/local/lib/python3.7/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Streamlit Application
# %%writefile app.py

import streamlit as st
import pandas as pd
import numpy as np

from math import pow, sqrt
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from fuzzywuzzy import process

import pickle
from imdb import IMDb

def recommend_movies(title_input, csim, movies, number_of_rec = 20):
    """
    title_input - title of the movie
    movies - dictionary of movie names and their Imdb ID
    """

    df12 = pd.read_csv("df_initial.csv", sep=',' )
    df12= df12[~pd.isna(df12['movieId'])]
    df12= df12[~pd.isna(df12['castId'])]
    df12.drop_duplicates(inplace=True)

    movieId_map = df12[['movieId', 'title']].drop_duplicates()
    castId_map = df12[['castId', 'primaryName']].drop_duplicates()

    movieIdMap = dict(zip(movieId_map['movieId'],movieId_map['title']))
    castIdMap = dict(zip(castId_map['castId'],castId_map['primaryName']))

    df12.drop(["title", "primaryName",  "imdbId",  "category"], axis=1, inplace=True)

    df_pivot = pd.DataFrame(df12.groupby(['movieId'])['castId'].apply(list))
    df_pivot['castId'] = df_pivot.apply(lambda row: ' '.join(row['castId']) , axis=1)
    movieIds = list(df_pivot.index)
    castIds = list(df_pivot['castId'])

    df_final = pd.DataFrame(csim, index=movieIds, columns=movieIds)
    movieTitles_list = list(movieId_map['title'])
    title_match = process.extractOne(title_input, movieTitles_list)[0]
    #st.subheader(f'Getting recommendation for {title_match}')

    primary_cast_bonus = .15  
    title = dict((v,k) for k,v in movieIdMap.items())
    movie_id_alpha = title[title_match] 
    if movie_id_alpha not in df_final.columns:
        st.write('Your film is not available. Try another one please')       #If the movie is not present on the platform
        movieFound = False  

    else:
        filtered_df = df_final[movie_id_alpha]
        recommendation = filtered_df.sort_values(ascending=False).head(number_of_rec+11)
        recommendation = pd.DataFrame(recommendation).reset_index(drop=False).rename(columns={'index':'movieId'}).merge(df_pivot, how='left', on=['movieId'])
        primary_cast_id = recommendation[recommendation['movieId'] == movie_id_alpha].iloc[0]['castId'].split()[0]  # gets the castId of the actor appearing first in the cast list
        recommendation = recommendation[recommendation['movieId'] != movie_id_alpha]   # drops the exact movie match
        recommendation[movie_id_alpha] = recommendation.apply(lambda row: row[movie_id_alpha] + primary_cast_bonus if primary_cast_id in row['castId'] else row[movie_id_alpha] , axis=1) # this checks the cast of each movie. If the primary actor is in it, it adds the "bonus" to the match score
        recommendation = recommendation.sort_values(by=movie_id_alpha , ascending=False).head(number_of_rec+1) # re-sorts the movies after adding any "bonus"
        movieFound = True

    if movieFound == True:
        recommendation['movieId'] = recommendation['movieId'].map(movieIdMap).fillna('N/A')
        recommendation['castId'] = recommendation['castId'].str.split()
        recommendation['castId'] = recommendation.apply(lambda row: ' . '.join([str(castIdMap[x]) for x in row['castId']]), axis=1) 
        

        # show recommended movies 
        st.subheader(f'Movies similar to - {title_input} based on cast and director:')

        # load IMDb to fetch cover posters
        imdb = IMDb()
        recommended_movies = recommendation['movieId'].unique().tolist()

        # display recommended movies in columns
        columns = [st.columns(4) for _ in range(5)] # 5 rows, 4 columns
        
        # segment movies too into columns 
        movie_column = []
        all_movies = []
        for idx, movie in enumerate(recommended_movies):
            if idx % 4 == 0:
                if movie_column:
                    all_movies.append(movie_column)
                    movie_column = []

            movie_column.append(movie)
        
        # display time!
        for movie_cols, cols in zip(all_movies, columns):
            for movie, column in zip(movie_cols, cols):
                if movie != 'N/A':
                    movie_id = movies[movie]
                    movie = imdb.get_movie(movie_id.lstrip('tt'))
                    
                    if 'cover url' in movie:
                        with column:
                            st.image(movie['cover url'], use_column_width=True)

        st.dataframe(recommendation)

def main():
    # load list of movie names
    with open('movie_names.pkl', 'rb') as f:
        movies = pickle.load(f)

    # read cosine similarity scores that we saved earlier
    with open('cosines.pkl', 'rb') as f:
        csim = pickle.load(f)

    # adding a blank value as default
    movie_names = list(movies.keys())
    movie_names.insert(0, '')

    # show pretty UI
    st.title('Movie Recommendation System')
    title_input = st.selectbox('Movie Name:', movie_names)
    
    if title_input:
        with st.spinner(f'Getting Recommendations for {title_input}'):
            recommend_movies(title_input, csim, movies)
            st.balloons()

    else:
        st.subheader('Enter a movie title to get started...')
 
    
if __name__ == '__main__':
    main()
# Out:
# Writing app.py

# %%
# run streamlit
# !streamlit run app.py --server.enableCORS=false &>/dev/null&
# !lt --Bypass-Tunnel-Reminder --subdomain 'meow' --port 8501
# Out:
# ^C

# %%
# kill app and clean up memory
st_id = !pgrep streamlit
# !kill {st_id[0]}

lt_id = !pgrep lt
# !kill {lt_id[0]}
